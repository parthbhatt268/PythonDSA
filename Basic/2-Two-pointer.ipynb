# %% [markdown]
# # Two pointer approach

# %% [markdown]
# - If you use Two pointer approach - think about sorting it first might help
# - In most case you use `while l < r:`
# - In most case you will update the l and r pointer in the else case

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# First approach------------------------>
class Solution:  # O(n), O(n)
    def isPalindrome(self, s: str) -> bool:
        str = ''

        for c in s:
            if c.isalnum():
                str += c.lower()
            
        return str == str[::-1]

# Second approach ------------------------->
class Solution: # O(n) O(1)
    def isPalindrome(self, s: str) -> bool:
        l, r = 0, len(s) - 1

        while l < r:
            while l < r and not self.isAlphaNum(s[l]):
                l += 1
            while r > l and not self.isAlphaNum(s[r]):
                r -= 1
            if s[l].lower() != s[r].lower():
                return False
            
            l, r = l+1, r-1
        return True

    def isAlphaNum (self, c):
        return (ord('A') <= ord(c) <= ord('Z') or
         ord('a') <= ord(c) <= ord('z') or
         ord('0') <= ord(c) <= ord('9'))
        

### Third approach - I thought of this approach :)

class Solution:
    def isPalindrome(self, s: str) -> bool:
        r, l = 0, len(s) - 1

        while r < l:
            # Skip non-alphanumeric characters
            while r < l and not s[r].isalnum():
                r += 1
            while r < l and not s[l].isalnum():
                l -= 1
            
            # Compare characters (case-insensitive)
            if s[r].lower() != s[l].lower():
                return False
            
            # Move pointers
            r += 1
            l -= 1
        
        return True
    
### Fourth approach - I thought of this approach :)
class Solution:
    def isPalindrome(self, s: str) -> bool:
        
        # 1: You filtered all unwanted stuff and make it lower and have CLEAN filetred stirng ready to be checked in next phase
        filtered = ''
        for i in s:
            if i.isalnum():
                filtered = filtered + i.lower()
            
        
        # 2: Now two pointer start and end to check them
        start, end = 0, len(filtered) - 1
        while start < end:
            if filtered[start] != filtered[end]:
                return False
            start += 1
            end -= 1
        
        return True
# Out:
# Running cells with 'Python 3.10.12' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# First approach - using two pointer - O(n), O(1) -------------------------------->
class Solution:
    def twoSum(self, numbers: List[int], target: int) -> List[int]:
        l, r = 0, len(numbers) - 1

        while l < r:
            curr = numbers[l] + numbers[r]

            if curr < target:
                l += 1
            elif curr > target:
                r -= 1
            else:
                return[l + 1, r + 1]
            
# Second approach using Hashmap - O(n), O(n) --------------------------------------->
class Solution:
    def twoSum(self, numbers: List[int], target: int) -> List[int]:
        mp = defaultdict(int)
        for i in range(len(numbers)):
            tmp = target - numbers[i]
            if mp[tmp]:
                return [mp[tmp], i + 1]
            mp[numbers[i]] = i + 1
        return []

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# First approach - two pointer - O(n^2), O(1)orO(n) based on sortting algo -------------------------------->
### 3 SUM - sorted, two pointer, enumerates
### Basically you just sort ti first and keep 2 loop first outer loop you just
# keep one number costant and on rest you just run the other loop with 2 SUm two pointe rtechnique

# and one thing to note is if you find current and prevoius
# is same then you skip it boz that would lead to duplicate triplet answer. <<<---IMP
class Solution:
    def threeSum(self, nums: List[int]) -> List[List[int]]:
        res = []
        nums.sort()

        for i, a in enumerate(nums):
            # Skip positive integers (boz if first number is
            # itself postive there is no way we can add any triplet
            # to get zero since there is not neagtive number at first place in sorted array)
            if a > 0:
                break

            if i > 0 and a == nums[i - 1]: # we did i>0 so that we dont check nums[i-1] on i -> 0th index boz it be undefined
                continue

            l, r = i + 1, len(nums) - 1
            while l < r:
                threeSum = a + nums[l] + nums[r]
                if threeSum > 0:
                    r -= 1
                elif threeSum < 0:
                    l += 1
                else:
                    res.append([a, nums[l], nums[r]])
                    l += 1
                    r -= 1
                    while nums[l] == nums[l - 1] and l < r: ### skipping duplicates
                        l += 1
                        
        return res

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# First approach - O(n), O(1)
class Solution:
    def maxArea(self, height: List[int]) -> int:
        res = 0

        l, r = 0, len(height) - 1

        while l < r:
            area = min(height[l], height[r]) * (r - l) # r and l are index here so no question of -ve number here
            res = max(area, res)

            if height[l] > height[r]:
                r -= 1
            
            else:
                l += 1
            
        return res

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class Solution:
    def trap(self, height: List[int]) -> int:
        if not height:
            return 0

        l, r = 0, len(height) - 1
        leftMax, rightMax = height[l], height[r]
        res = 0
        while l < r:
            if leftMax < rightMax:
                l += 1
                leftMax = max(leftMax, height[l])
                res += leftMax - height[l]
            else:
                r -= 1
                rightMax = max(rightMax, height[r])
                res += rightMax - height[r]
        return res
