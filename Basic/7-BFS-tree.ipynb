# %%
# BFS - Level Order Traversal of a Binary Tree - LC 102


class Solution:
    def levelOrder(self, root: Optional[TreeNode]) -> List[List[int]]:
        res = []
        q = deque()
        q.append(root)

        while q:
            level = []
            qLen = len(q)
            for i in range(qLen):
                node = q.popleft()
                if node:
                    level.append(node.val)
                    q.append(node.left)
                    q.append(node.right)
            if level:
                res.append(level)
        
        return res

# %%
# Rotten Oranges LC994 / Same as Covid Spread Problem

from typing import List
from collections import deque

class Solution:
    def orangesRotting(self, grid: List[List[int]]) -> int:
        r = len(grid)
        c = len(grid[0])

        # BFS
        q = deque()
        fresh = 0

        # Push all initially rotten oranges into queue
        for i in range(r):
            for j in range(c):
                if grid[i][j] == 1:
                    fresh += 1
                if grid[i][j] == 2:
                    q.append((i, j))

        # Edeg case if no fresh orange we skip and retunr 0
        if fresh == 0:
            return 0

        row = [1, -1, 0, 0]
        col = [0, 0, 1, -1]

        def valid(i: int, j: int) -> bool:
            return 0 <= i < r and 0 <= j < c

        timer = 0

        while q:
            timer += 1
            curr_patient = len(q)

            while curr_patient > 0:
                i, j = q.popleft()
                curr_patient -= 1

                for k in range(4):
                    ni = i + row[k]
                    nj = j + col[k]

                    if valid(ni, nj) and grid[ni][nj] == 1:
                        grid[ni][nj] = 2
                        q.append((ni, nj))

        # Check if any fresh orange remains
        for i in range(r):
            for j in range(c):
                if grid[i][j] == 1:
                    return -1

     
        return timer-1

# %%
# Find if Path Exists in Graph LC1971

class Solution:
    def validPath(self, n: int, edges: List[List[int]], source: int, destination: int) -> bool:
        if source == destination:
            return True
        # create adj list
        adj = [[] for i in range(n)]
        for u, v in edges:
            adj[u].append(v)
            adj[v].append(u)
        
        visited = [False] * n
        q = deque()
        q.append(source)
        visited[source] = True

        while q:
            node = q.popleft()
            if node == destination:
                return True
            
            for k in adj[node]:
                if not visited[k]:
                    visited[k] = True
                    q.append(k)

        return False
